# %%
# Modulation Recognition: NEU

from matplotlib import pyplot as plt    
plt.rcParams["font.family"] = "Times New Roman"


import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

d= np.array([[51.42, 72.58, 93.03],[50.58, 68.31, 92.73],[51.97, 52.63, 98.68]])    # gps,img,lidar,all 
d= d*0.01



# stds = np.array([[3.018676862,2.356217307,2.333125943,2.222917002],[7.523796618,3.856220948,2.206801607,3.303879201],[3.735202508,1.765655056,1.719134149,3.285939744],[5.101632092,3.987449756,4.257772109,2.846566938],[4.426380638,1.597294936,1.497114261,1.380016506]])
# stds = stds *0.01

# df = pd.DataFrame(d, columns=['IQ','CSP','Fusion'])
df = pd.DataFrame(d, columns=['Pl 2','Pl 3','Pl 4'])
#stds_f = pd.DataFrame(stds, columns=['IQ','CSP','Fusion'])
print(df)
# print(stds_f)
ax = plt.figure(figsize=(5,3)).add_subplot(111)

plots = df.plot(ax=ax, kind='bar',width=0.8,color=['#FFA07A','#9FE2BF','#CCCCFF'],edgecolor='black',legend=False)

bars = ax.patches
hatches = ''.join(h*len(df) for h in 'xo\.')
for bar, hatch in zip(bars, hatches):
    bar.set_hatch(hatch)
    ######################################
    plots.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() ,
                    bar.get_height()), ha='right', va='center',
                   size=12, xytext=(0, 5),  weight='bold',
                   textcoords='offset points')
    ######################################
    
# ax.legend(loc='center right', bbox_to_anchor=(1.01, 1.2), ncol=6,fontsize=14)
ax.set_xticklabels(('131072', '262144', '524288'))
plt.xticks(fontsize=20,rotation=0)
plt.yticks(fontsize=20)
plt.ylabel('Accuracy', fontsize=20)
axes = plt.gca()
axes.set_ylim([0.4, 1.1])

###############################
ax.spines["right"].set_visible(False)
ax.spines["top"].set_visible(False)
##############################

plt.savefig('t-SNE/modulation_accuracy_NEU.png',bbox_inches='tight',dpi=1200)
plt.show()
# Out:
#      Pl 2    Pl 3    Pl 4
# 0  0.5142  0.7258  0.9303
# 1  0.5058  0.6831  0.9273
# 2  0.5197  0.5263  0.9868

# %%
# Anomaly Detection: NEU

from matplotlib import pyplot as plt    
plt.rcParams["font.family"] = "Times New Roman"


import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

d= np.array([[61.38, 99.81, 99.81, 99.81],[69.30, 99.6, 100, 100],[80.19,92.38, 99.1, 99.1]])    # gps,img,lidar,all 
d= d*0.01
# stds = np.array([[3.018676862,2.356217307,2.333125943,2.222917002],[7.523796618,3.856220948,2.206801607,3.303879201],[3.735202508,1.765655056,1.719134149,3.285939744],[5.101632092,3.987449756,4.257772109,2.846566938],[4.426380638,1.597294936,1.497114261,1.380016506]])
# stds = stds *0.01

# df = pd.DataFrame(d, columns=['IQ','CSP','Fusion'])
df = pd.DataFrame(d, columns=['Pl 1', 'Pl 2','Pl 3','Pl 4'])
#stds_f = pd.DataFrame(stds, columns=['IQ','CSP','Fusion'])
print(df)
# print(stds_f)
ax = plt.figure(figsize=(5,3)).add_subplot(111)
plots = df.plot(ax=ax, kind='bar',width=0.8,color=['#6495ED', '#FFA07A','#9FE2BF','#CCCCFF'],edgecolor='black',legend=False)

bars = ax.patches
hatches = ''.join(h*len(df) for h in 'xo\.')
for bar, hatch in zip(bars, hatches):
    bar.set_hatch(hatch)
    ######################################
    plots.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() ,
                    bar.get_height()), ha='right', va='center',
                   size=10, xytext=(0, 5),  weight='bold',
                   textcoords='offset points')
    ######################################
    
# ax.legend(loc='center right', bbox_to_anchor=(1.01, 1.2), ncol=6,fontsize=14)
ax.set_xticklabels(('131072', '262144', '524288'))
plt.xticks(fontsize=20,rotation=0)
plt.yticks(fontsize=20)
plt.ylabel('Accuracy', fontsize=20)
axes = plt.gca()
axes.set_ylim([0.2, 1.1])
###############################
ax.spines["right"].set_visible(False)
ax.spines["top"].set_visible(False)
##############################
plt.savefig('t-SNE/anomaly_accuracy_NEU.png',bbox_inches='tight',dpi=1200)
plt.show()
# Out:
#      Pl 1    Pl 2    Pl 3    Pl 4
# 0  0.6138  0.9981  0.9981  0.9981
# 1  0.6930  0.9960  1.0000  1.0000
# 2  0.8019  0.9238  0.9910  0.9910

# %%
# Modulation Recignition: NWRA

from matplotlib import pyplot as plt    
plt.rcParams["font.family"] = "Times New Roman"


import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

d= np.array([[62.17, 66.16, 75],[65.17, 68.52, 68.52],[67.52, 70.58,  70.58]])    # gps,img,lidar,all 
d= d*0.01


# stds = np.array([[3.018676862,2.356217307,2.333125943,2.222917002],[7.523796618,3.856220948,2.206801607,3.303879201],[3.735202508,1.765655056,1.719134149,3.285939744],[5.101632092,3.987449756,4.257772109,2.846566938],[4.426380638,1.597294936,1.497114261,1.380016506]])
# stds = stds *0.01

# df = pd.DataFrame(d, columns=['IQ','CSP','Fusion'])
df = pd.DataFrame(d, columns=['P2','P3','P4'])
#stds_f = pd.DataFrame(stds, columns=['IQ','CSP','Fusion'])
print(df)
# print(stds_f)
ax = plt.figure(figsize=(5,3)).add_subplot(111)
plots = df.plot(ax=ax, kind='bar',width=0.8,color=['#FFA07A','#9FE2BF','#CCCCFF'],edgecolor='black',legend=False)

bars = ax.patches
hatches = ''.join(h*len(df) for h in 'xo\.')
for bar, hatch in zip(bars, hatches):
    bar.set_hatch(hatch)
    ######################################
    plots.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() ,
                    bar.get_height()), ha='right', va='center',
                   size=12, xytext=(0, 5),  weight='bold',
                   textcoords='offset points')
    ######################################
    
ax.legend(loc='center right', bbox_to_anchor=(1.01, 1.2), ncol=6,fontsize=20)
ax.set_xticklabels(('131072', '262144', '524288'))
plt.xticks(fontsize=20,rotation=0)
# plt.yticks(fontsize=20)
# plt.ylabel('Accuracy', fontsize=20)
axes = plt.gca()
axes.set_ylim([0.4, 1.1])
###############################
ax.spines["left"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.spines["top"].set_visible(False)
##############################

plt.savefig('t-SNE/modulation_accuracy_NWRA.png',bbox_inches='tight',dpi=1200)
plt.show()
# Out:
#        P2      P3      P4
# 0  0.6217  0.6616  0.7500
# 1  0.6517  0.6852  0.6852
# 2  0.6752  0.7058  0.7058

# %%
# Anomaly Detection: NWRA

from matplotlib import pyplot as plt    
plt.rcParams["font.family"] = "Times New Roman"


import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

d= np.array([[75.80, 96.75, 80.62, 98.95],[81.77, 93.75, 81.16, 97.96],[83.22, 97.5, 84.7, 98.25]])    # gps,img,lidar,all 
d= d*0.01
# stds = np.array([[3.018676862,2.356217307,2.333125943,2.222917002],[7.523796618,3.856220948,2.206801607,3.303879201],[3.735202508,1.765655056,1.719134149,3.285939744],[5.101632092,3.987449756,4.257772109,2.846566938],[4.426380638,1.597294936,1.497114261,1.380016506]])
# stds = stds *0.01

# df = pd.DataFrame(d, columns=['IQ','CSP','Fusion'])
df = pd.DataFrame(d, columns=['Pl 1', 'Pl 2','Pl 3','Pl 4'])
#stds_f = pd.DataFrame(stds, columns=['IQ','CSP','Fusion'])
print(df)
# print(stds_f)
ax = plt.figure(figsize=(5,3)).add_subplot(111)
plots = df.plot(ax=ax, kind='bar',width=0.8,color=['#6495ED', '#FFA07A','#9FE2BF','#CCCCFF'],edgecolor='black',legend=False)

bars = ax.patches
hatches = ''.join(h*len(df) for h in 'xo\.')
for bar, hatch in zip(bars, hatches):
    bar.set_hatch(hatch)
    ######################################
    plots.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() ,
                    bar.get_height()), ha='right', va='center',
                   size=10, xytext=(0, 5),  weight='bold',
                   textcoords='offset points')
    ######################################
    
ax.legend(loc='center right', bbox_to_anchor=(1.01, 1.2), ncol=6,fontsize=20)
ax.set_xticklabels(('131072', '262144', '524288'))
plt.xticks(fontsize=20,rotation=0)
# plt.yticks(fontsize=20)
# plt.ylabel('Accuracy', fontsize=20)
axes = plt.gca()
axes.set_ylim([0.2, 1.1])
###############################
ax.spines["right"].set_visible(False)
ax.spines["left"].set_visible(False)
ax.spines["top"].set_visible(False)
##############################
plt.savefig('t-SNE/anomaly_accuracy_NWRA.png',bbox_inches='tight',dpi=1200)
plt.show()
# Out:
#      Pl 1    Pl 2    Pl 3    Pl 4
# 0  0.7580  0.9675  0.8062  0.9895
# 1  0.8177  0.9375  0.8116  0.9796
# 2  0.8322  0.9750  0.8470  0.9825

# %%
# Modulation Recognition: POWDER


from matplotlib import pyplot as plt    
plt.rcParams["font.family"] = "Times New Roman"


import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

d= np.array([[66.67, 52.18, 66.67],[69.64, 47.19, 92.85],[51.04, 62.5, 90.62]])    # gps,img,lidar,all 
d= d*0.01
# stds = np.array([[3.018676862,2.356217307,2.333125943,2.222917002],[7.523796618,3.856220948,2.206801607,3.303879201],[3.735202508,1.765655056,1.719134149,3.285939744],[5.101632092,3.987449756,4.257772109,2.846566938],[4.426380638,1.597294936,1.497114261,1.380016506]])
# stds = stds *0.01



# df = pd.DataFrame(d, columns=['IQ','CSP','Fusion'])
df = pd.DataFrame(d, columns=['Pl 2','Pl 3','Pl 4'])
#stds_f = pd.DataFrame(stds, columns=['IQ','CSP','Fusion'])
print(df)
# print(stds_f)
ax = plt.figure(figsize=(5,3)).add_subplot(111)
plots = df.plot(ax=ax, kind='bar',width=0.8,color=['#FFA07A','#9FE2BF','#CCCCFF'],edgecolor='black',legend=False)

bars = ax.patches
hatches = ''.join(h*len(df) for h in 'xo\.')
for bar, hatch in zip(bars, hatches):
    bar.set_hatch(hatch)
    ######################################
    plots.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() ,
                    bar.get_height()), ha='right', va='center',
                   size=12, xytext=(0, 5),  weight='bold',
                   textcoords='offset points')
    ######################################
    
# ax.legend(loc='center right', bbox_to_anchor=(1.01, 1.2), ncol=6,fontsize=18)
ax.set_xticklabels(('131072', '262144', '524288'))
plt.xticks(fontsize=20,rotation=0)
# plt.yticks(fontsize=20)
# plt.ylabel('Accuracy', fontsize=20)
axes = plt.gca()
axes.set_ylim([0.4, 1.1])
###############################
ax.spines["left"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.spines["top"].set_visible(False)
##############################
plt.savefig('t-SNE/modulation_accuracy_POWDER.png',bbox_inches='tight',dpi=1200)
plt.show()
# Out:
#      Pl 2    Pl 3    Pl 4
# 0  0.6667  0.5218  0.6667
# 1  0.6964  0.4719  0.9285
# 2  0.5104  0.6250  0.9062

# %%
# Anomaly Detection: POWDER


from matplotlib import pyplot as plt    
plt.rcParams["font.family"] = "Times New Roman"


import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

d= np.array([[50.68, 100, 62.01, 100],[32.56, 100, 80.68, 100],[22.32, 100, 83.33, 100]])    # gps,img,lidar,all 
d= d*0.01
# stds = np.array([[3.018676862,2.356217307,2.333125943,2.222917002],[7.523796618,3.856220948,2.206801607,3.303879201],[3.735202508,1.765655056,1.719134149,3.285939744],[5.101632092,3.987449756,4.257772109,2.846566938],[4.426380638,1.597294936,1.497114261,1.380016506]])
# stds = stds *0.01

# df = pd.DataFrame(d, columns=['IQ','CSP','Fusion'])
df = pd.DataFrame(d, columns=['Pl 1', 'Pl 2','Pl 3','Pl 4'])
#stds_f = pd.DataFrame(stds, columns=['IQ','CSP','Fusion'])
print(df)
# print(stds_f)
ax = plt.figure(figsize=(5,3)).add_subplot(111)
plots = df.plot(ax=ax, kind='bar',width=0.8,color=['#6495ED', '#FFA07A','#9FE2BF','#CCCCFF'],edgecolor='black',legend=False)

bars = ax.patches
hatches = ''.join(h*len(df) for h in 'xo\.')
for bar, hatch in zip(bars, hatches):
    bar.set_hatch(hatch)
    ######################################
    plots.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() ,
                    bar.get_height()), ha='right', va='center',
                   size=10, xytext=(0, 5),  weight='bold',
                   textcoords='offset points')
    ######################################
    
# ax.legend(loc='center right', bbox_to_anchor=(1.01, 1.2), ncol=6,fontsize=14)
ax.set_xticklabels(('131072', '262144', '524288'))
plt.xticks(fontsize=20,rotation=0)
# plt.yticks(fontsize=20)
# plt.ylabel('Accuracy', fontsize=20)
axes = plt.gca()
axes.set_ylim([0.2, 1.1])
###############################
ax.spines["left"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.spines["top"].set_visible(False)
##############################
plt.savefig('t-SNE/anomaly_accuracy_POWDER.png',bbox_inches='tight',dpi=1200)
plt.show()
# Out:
#      Pl 1  Pl 2    Pl 3  Pl 4
# 0  0.5068   1.0  0.6201   1.0
# 1  0.3256   1.0  0.8068   1.0
# 2  0.2232   1.0  0.8333   1.0

# %%
# Comparision of Inference Times
from matplotlib import pyplot as plt    
plt.rcParams["font.family"] = "Times New Roman"


import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

d= np.array([[1, 0.093, 0.09, 0.18],[1, 0.0337, 0.034, 0.0627],[1, 0.00337, 0.0034, 0.00627]])  # gps,img,lidar,all 
#d= d*0.01
stds = np.array([[0.2,0.0444, 0.04448,0.04637],[0.2,0.0244, 0.02448,0.02637],[0.2,0.00244, 0.002448,0.002637]])
#stds = stds *0.01

df = pd.DataFrame(d, columns=['PL 1', 'Pl 2', 'Pl 3', 'Pl 4'])
stds_f = pd.DataFrame(stds, columns=['PL 1', 'Pl 2', 'Pl 3', 'Pl 4'])
print(df)
print(stds_f)
ax = plt.figure(figsize=(10,3)).add_subplot(111)
df.plot(ax=ax, kind='bar',width=0.8,color=['#FBEAE9','#FAE4D8','#FBD6AB','#F1AF79'],edgecolor='black',yerr=stds_f,legend=False,error_kw=dict(lw=2, capsize=5, capthick=2.5,color='red'))

bars = ax.patches
hatches = ''.join(h*len(df) for h in 'xo\.')
for bar, hatch in zip(bars, hatches):
    bar.set_hatch(hatch)
    
ax.legend(loc='center right', bbox_to_anchor=(1.01, 1.2), ncol=6,fontsize=14)
ax.set_xticklabels(('Jetson TX2', '2080Ti', 'A100'))
plt.xticks(fontsize=15,rotation=0)
plt.yticks(fontsize=15)
plt.ylabel('Inference Time (s)', fontsize=15)
axes = plt.gca()
axes.set_ylim([0,0.2])
plt.savefig('inference_time_error_bar.png',bbox_inches='tight',dpi=1200)
plt.show()
# Out:
#    PL 1     Pl 2    Pl 3     Pl 4
# 0   1.0  0.09300  0.0900  0.18000
# 1   1.0  0.03370  0.0340  0.06270
# 2   1.0  0.00337  0.0034  0.00627
#    PL 1     Pl 2      Pl 3      Pl 4
# 0   0.2  0.04440  0.044480  0.046370
# 1   0.2  0.02440  0.024480  0.026370
# 2   0.2  0.00244  0.002448  0.002637

# %%
# Inference times: Jul 23 (mean and variance)
from matplotlib import pyplot as plt    
plt.rcParams["font.family"] = "Times New Roman"


import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

d= np.array([[1, 34.55629767, 0.0003614666667, 64.36317347],[1, 0.28357663, 0.04331340327, 0.292869072],[1, 0.02834833233, 0.0004350284333, 0.03849287933]])  
stds = np.array([[0.2,30.15299529, 0.00003787892994, 43.96693391],[0.2,0.01239078493, 0.02943489396, 0.01364347705],[0.2,0.002903403384, 0.0000447171152, 0.007509752109]])
#stds = stds *0.01



df = pd.DataFrame(d, columns=['PL 1', 'Pl 2', 'Pl 3', 'Pl 4'])
stds_f = pd.DataFrame(stds, columns=['PL 1', 'Pl 2', 'Pl 3', 'Pl 4'])
print(df)
print(stds_f)
ax = plt.figure(figsize=(10,3)).add_subplot(111)
df.plot(ax=ax, kind='bar',width=0.8,color=['#FBEAE9','#FAE4D8','#FBD6AB','#F1AF79'],edgecolor='black',yerr=stds_f,legend=False,error_kw=dict(lw=2, capsize=5, capthick=2.5,color='red'))

bars = ax.patches
hatches = ''.join(h*len(df) for h in 'xo\.')
for bar, hatch in zip(bars, hatches):
    bar.set_hatch(hatch)

# plt.scatter(x, y, c=colors)    
    
ax.legend(loc='center right', bbox_to_anchor=(1.01, 1.2), ncol=6,fontsize=14)
ax.set_xticklabels(('Intel i7 CPU', '2080Ti', 'A100'))
plt.xticks(fontsize=15,rotation=0)
plt.yticks(fontsize=15)
plt.ylabel('Inference Time (s)', fontsize=15)
axes = plt.gca()
axes.set_ylim([0,1])
plt.savefig('inference_time_error_bar.png',bbox_inches='tight',dpi=1200)
plt.show()
# Out:
#    PL 1       Pl 2      Pl 3       Pl 4
# 0   1.0  34.556298  0.000361  64.363173
# 1   1.0   0.283577  0.043313   0.292869
# 2   1.0   0.028348  0.000435   0.038493
#    PL 1       Pl 2      Pl 3       Pl 4
# 0   0.2  30.152995  0.000038  43.966934
# 1   0.2   0.012391  0.029435   0.013643
# 2   0.2   0.002903  0.000045   0.007510

# %%
# Inference times: Jul 23 (mean and variance)
from matplotlib import pyplot as plt    
plt.rcParams["font.family"] = "Times New Roman"


import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

d= np.array([[1, 34.55629767, 0.0003614666667, 64.36317347],[1, 0.28357663, 0.04331340327, 0.292869072],[1, 0.02834833233, 0.0004350284333, 0.03849287933]])  
stds = np.array([[0.2,30.15299529, 0.00003787892994, 43.96693391],[0.2,0.01239078493, 0.02943489396, 0.01364347705],[0.2,0.002903403384, 0.0000447171152, 0.007509752109]])
#stds = stds *0.01



df = pd.DataFrame(d, columns=['PL 1', 'Pl 2', 'Pl 3', 'Pl 4'])
stds_f = pd.DataFrame(stds, columns=['PL 1', 'Pl 2', 'Pl 3', 'Pl 4'])
print(df)
print(stds_f)
ax = plt.figure(figsize=(10,3)).add_subplot(111)
df.plot(ax=ax, kind='bar',width=0.8,color=['#FBEAE9','#FAE4D8','#FBD6AB','#F1AF79'],edgecolor='black', legend=False,error_kw=dict(lw=2, capsize=5, capthick=2.5,color='red'))

bars = ax.patches
hatches = ''.join(h*len(df) for h in 'xo\.')
for bar, hatch in zip(bars, hatches):
    bar.set_hatch(hatch)

# plt.scatter(x, y, c=colors)    
    
ax.legend(loc='center right', bbox_to_anchor=(1.01, 1.2), ncol=6,fontsize=14)
ax.set_xticklabels(('Intel i7 CPU', '2080Ti', 'A100'))
plt.xticks(fontsize=15,rotation=0)
plt.yticks(fontsize=15)
plt.ylabel('Inference Time (s)', fontsize=15)
axes = plt.gca()
axes.set_ylim([0,0.2])
plt.savefig('inference_time_error_bar.png',bbox_inches='tight',dpi=1200)
plt.show()
# Out:
#    PL 1       Pl 2      Pl 3       Pl 4
# 0   1.0  34.556298  0.000361  64.363173
# 1   1.0   0.283577  0.043313   0.292869
# 2   1.0   0.028348  0.000435   0.038493
#    PL 1       Pl 2      Pl 3       Pl 4
# 0   0.2  30.152995  0.000038  43.966934
# 1   0.2   0.012391  0.029435   0.013643
# 2   0.2   0.002903  0.000045   0.007510

# %%
from matplotlib import pyplot as plt    
plt.rcParams["font.family"] = "Times New Roman"


import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

d= np.array([[16.651,22.896,19.73,23.374],[30.644,29.218,23.362,28.498],[20.826,24.294,20.91,24.73],[31.145,27.87,23.983,26.979],[24.537,25.702,21.792,25.387]])    # gps,img,lidar,all 
d= d*0.01
stds = np.array([[3.018676862,2.356217307,2.333125943,2.222917002],[7.523796618,3.856220948,2.206801607,3.303879201],[3.735202508,1.765655056,1.719134149,3.285939744],[5.101632092,3.987449756,4.257772109,2.846566938],[4.426380638,1.597294936,1.497114261,1.380016506]])
stds = stds *0.01

df = pd.DataFrame(d, columns=['Coordinate','Image','LiDAR','Fusion'])
stds_f = pd.DataFrame(stds, columns=['Coordinate','Image','LiDAR','Fusion'])
print(df)
print(stds_f)
ax = plt.figure(figsize=(10,3)).add_subplot(111)
df.plot(ax=ax, kind='bar',width=0.8,color=['#FBEAE9','#FAE4D8','#FBD6AB','#F1AF79'],edgecolor='black',yerr=stds_f,legend=False,error_kw=dict(lw=2, capsize=5, capthick=2.5,color='red'))

bars = ax.patches
hatches = ''.join(h*len(df) for h in 'xo\.')
for bar, hatch in zip(bars, hatches):
    bar.set_hatch(hatch)
    
ax.legend(loc='center right', bbox_to_anchor=(1.01, 1.2), ncol=6,fontsize=14)
ax.set_xticklabels(('Category 1', 'Category 2', 'Category 3', 'Category 4','Combined'))
plt.xticks(fontsize=15,rotation=0)
plt.yticks(fontsize=15)
plt.ylabel('Top-1 Accuracy', fontsize=15)
axes = plt.gca()
axes.set_ylim([0,0.5])
plt.savefig('figs/top1_accuracy_error_bar.png',bbox_inches='tight',dpi=400)
plt.show()
# Out:
#    Coordinate    Image    LiDAR   Fusion
# 0     0.16651  0.22896  0.19730  0.23374
# 1     0.30644  0.29218  0.23362  0.28498
# 2     0.20826  0.24294  0.20910  0.24730
# 3     0.31145  0.27870  0.23983  0.26979
# 4     0.24537  0.25702  0.21792  0.25387
#    Coordinate     Image     LiDAR    Fusion
# 0    0.030187  0.023562  0.023331  0.022229
# 1    0.075238  0.038562  0.022068  0.033039
# 2    0.037352  0.017657  0.017191  0.032859
# 3    0.051016  0.039874  0.042578  0.028466
# 4    0.044264  0.015973  0.014971  0.013800
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-20-2b9b416e0d19> in <module>
#      31 axes = plt.gca()
#      32 axes.set_ylim([0,0.5])
# ---> 33 plt.savefig('figs/top1_accuracy_error_bar.png',bbox_inches='tight',dpi=400)
#      34 plt.show()
#
# /usr/local/lib/python3.6/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
# ...
